# %%
import requests
import csv
from bs4 import BeautifulSoup as bs

url = requests.get("http://www.ciclt.net/sn/clt/capitolimpact/gw_ziplist.aspx?FIPS=53033")
soup = bs(url.content, 'html.parser')

filename = "kc_zips.csv"
csv_writer = csv.writer(open(filename, 'w'))


for tr in soup.find_all("tr"):
    data = []
    # for headers ( entered only once - the first time - )
    for th in tr.find_all("th"):
        data.append(th.text)
    if data:
        print("Inserting headers : {}".format(','.join(data)))
        csv_writer.writerow(data)
        continue

    for td in tr.find_all("td"):
        if td.a:
            data.append(td.a.text.strip())
        else:
            data.append(td.text.strip())
    if data:
        print("Inserting data: {}".format(','.join(data)))
        csv_writer.writerow(data)
# Out:
# Inserting data:
# Inserting headers : Zip Code,City,County,Zip Code,City,County,Zip Code,City,County
# Inserting headers : Zip Code,City,County,Zip Code,City,County,Zip Code,City,County
# Inserting headers : Zip Code,City,County
# Inserting data: 98001,Algona,King County
# Inserting data: 98001,Auburn,King County
# Inserting data: 98001,Federal Way,King County
# Inserting data: 98002,Auburn,King County
# Inserting data: 98003,Auburn,King County
# Inserting data: 98003,Federal Way,King County
# Inserting data: 98004,Beaux Arts Village,King County
# Inserting data: 98004,Bellevue,King County
# Inserting data: 98004,Clyde Hill,King County
# Inserting data: 98004,Hunts Point,King County
# Inserting data: 98004,Yarrow Point,King County
# Inserting data: 98005,Bellevue,King County
# Inserting data: 98006,Bellevue,King County
# Inserting data: 98007,Bellevue,King County
# Inserting data: 98008,Bellevue,King County
# Inserting data: 98009,Bellevue,King County
# Inserting data: 98010,Black Diamond,King County
# Inserting data: 98011,Bothell,King County
# Inserting data: 98013,Burton,King County
# Inserting data: 98013,Vashon,King County
# Inserting data: 98014,Carnation,King County
# Inserting data: 98015,Bellevue,King County
# Inserting data: 98019,Duvall,King County
# Inserting data: 98022,Enumclaw,King County
# Inserting data: 98023,Auburn,King County
# Inserting data: 98023,Federal Way,King County
# Inserting data: 98024,Fall City,King County
# Inserting data: 98025,Hobart,King County
# Inserting data: 98027,Issaquah,King County
# Inserting data: 98028,Kenmore,King County
# Inserting data: 98028,Bothell,King County
# Inserting data: 98029,Issaquah,King County
# Inserting data: 98030,Kent,King County
# Inserting data: 98031,Kent,King County
# Inserting data: 98032,Kent,King County
# Inserting data: 98033,Kirkland,King County
# Inserting data: 98034,Kirkland,King County
# Inserting data: 98035,Kent,King County
# Inserting data: 98038,Maple Valley,King County
# Inserting data: 98039,Medina,King County
# Inserting data: 98040,Mercer Island,King County
# Inserting data: 98041,Bothell,King County
# Inserting data: 98042,Covington,King County
# Inserting data: 98042,Kent,King County
# Inserting data: 98045,North Bend,King County
# Inserting data: 98047,Auburn,King County
# Inserting data: 98047,Pacific,King County
# Inserting data: 98050,Preston,King County
# Inserting data: 98051,Ravensdale,King County
# Inserting data: 98052,Redmond,King County
# Inserting data: 98053,Redmond,King County
# Inserting data: 98054,Redondo,King County
# Inserting headers : Zip Code,City,County
# Inserting data: 98055,Renton,King County
# Inserting data: 98056,Newcastle,King County
# Inserting data: 98056,Renton,King County
# Inserting data: 98057,Renton,King County
# Inserting data: 98058,Renton,King County
# Inserting data: 98059,Newcastle,King County
# Inserting data: 98059,Renton,King County
# Inserting data: 98062,Seahurst,King County
# Inserting data: 98063,Auburn,King County
# Inserting data: 98063,Federal Way,King County
# Inserting data: 98064,Kent,King County
# Inserting data: 98065,Snoqualmie,King County
# Inserting data: 98068,Snoqualmie Pass,King County
# Inserting data: 98068,Snoqualmie,King County
# Inserting data: 98070,Vashon,King County
# Inserting data: 98071,Auburn,King County
# Inserting data: 98072,Woodinville,King County
# Inserting data: 98073,Redmond,King County
# Inserting data: 98074,Sammamish,King County
# Inserting data: 98074,Redmond,King County
# Inserting data: 98075,Sammamish,King County
# Inserting data: 98075,Issaquah,King County
# Inserting data: 98083,Kirkland,King County
# Inserting data: 98092,Auburn,King County
# Inserting data: 98093,Auburn,King County
# Inserting data: 98093,Federal Way,King County
# Inserting data: 98101,Seattle,King County
# Inserting data: 98102,Seattle,King County
# Inserting data: 98103,Seattle,King County
# Inserting data: 98104,Seattle,King County
# Inserting data: 98105,Seattle,King County
# Inserting data: 98106,Seattle,King County
# Inserting data: 98107,Seattle,King County
# Inserting data: 98108,Seattle,King County
# Inserting data: 98108,Tukwila,King County
# Inserting data: 98109,Seattle,King County
# Inserting data: 98111,Seattle,King County
# Inserting data: 98112,Seattle,King County
# Inserting data: 98114,Seattle,King County
# Inserting data: 98115,Seattle,King County
# Inserting data: 98116,Seattle,King County
# Inserting data: 98117,Seattle,King County
# Inserting data: 98118,Seattle,King County
# Inserting data: 98119,Seattle,King County
# Inserting data: 98121,Seattle,King County
# Inserting data: 98122,Seattle,King County
# Inserting data: 98124,Seattle,King County
# Inserting data: 98125,Seattle,King County
# Inserting data: 98126,Seattle,King County
# Inserting data: 98131,Seattle,King County
# Inserting data: 98132,Seattle,King County
# Inserting headers : Zip Code,City,County
# Inserting data: 98133,Seattle,King County
# Inserting data: 98133,Shoreline,King County
# Inserting data: 98134,Seattle,King County
# Inserting data: 98136,Seattle,King County
# Inserting data: 98138,Seattle,King County
# Inserting data: 98138,Tukwila,King County
# Inserting data: 98144,Seattle,King County
# Inserting data: 98145,Seattle,King County
# Inserting data: 98146,Burien,King County
# Inserting data: 98146,Seattle,King County
# Inserting data: 98148,Burien,King County
# Inserting data: 98148,Des Moines,King County
# Inserting data: 98148,Normandy Park,King County
# Inserting data: 98148,Seatac,King County
# Inserting data: 98148,Seattle,King County
# Inserting data: 98154,Seattle,King County
# Inserting data: 98155,Lk Forest Park,King County
# Inserting data: 98155,Lk Forest Pk,King County
# Inserting data: 98155,Lake Forest Park,King County
# Inserting data: 98155,Seattle,King County
# Inserting data: 98155,Shoreline,King County
# Inserting data: 98158,Seatac,King County
# Inserting data: 98158,Seattle,King County
# Inserting data: 98160,Seattle,King County
# Inserting data: 98161,Seattle,King County
# Inserting data: 98164,Seattle,King County
# Inserting data: 98166,Burien,King County
# Inserting data: 98166,Normandy Park,King County
# Inserting data: 98166,Seattle,King County
# Inserting data: 98168,Burien,King County
# Inserting data: 98168,Seatac,King County
# Inserting data: 98168,Seattle,King County
# Inserting data: 98168,Tukwila,King County
# Inserting data: 98171,Seattle,King County
# Inserting data: 98174,Seattle,King County
# Inserting data: 98177,Seattle,King County
# Inserting data: 98177,Shoreline,King County
# Inserting data: 98178,Seattle,King County
# Inserting data: 98178,Tukwila,King County
# Inserting data: 98188,Seatac,King County
# Inserting data: 98188,Seattle,King County
# Inserting data: 98188,Tukwila,King County
# Inserting data: 98198,Des Moines,King County
# Inserting data: 98198,Normandy Park,King County
# Inserting data: 98198,Seatac,King County
# Inserting data: 98198,Seattle,King County
# Inserting data: 98199,Seattle,King County
# Inserting data: 98224,Baring,King County
# Inserting data: 98288,Skykomish,King County
# Inserting data:
# <_csv.writer object at 0x1061f0728>

# %%
import csv
import requests
from bs4 import BeautifulSoup

link = "http://www.ciclt.net/sn/clt/capitolimpact/gw_ziplist.aspx?FIPS=53033"

def get_data(link):
    for url in [link.format(page) for page in range(1,6)]:
        res = requests.get(url)
        soup = BeautifulSoup(res.text,"lxml")

        for items in soup.select("table.table tr"):
            td = [item.get_text(strip=True) for item in items.select("th,td")]
            writer.writerow(td)

if __name__ == '__main__':
    with open("tabularitem.csv","w",newline="") as infile: #if encoding issue comes up then replace with ('tabularitem.csv', 'w', newline="", encoding="utf-8")
        writer = csv.writer(infile)
        get_data(link)
